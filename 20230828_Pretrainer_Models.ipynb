# %% [markdown]
# <a href="https://colab.research.google.com/github/adrianfraile95/Crypto_Clustering/blob/main/20230828_Pretrainer_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import os
import numpy as np

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %%
model = VGG19(include_top =True, weights='imagenet')
# Out:
# ...
# 574710816/574710816 [==============================] - 3s 0us/step

# %%
image_path = 'https://static.bc-edx.com/data/dl-1-2/m23/lessons/2/img/bird1.jpg'

from urllib.request import urlopen
from io import BytesIO

with urlopen(image_path) as raw:
  img = image.load_img(BytesIO(raw.read()), target_size=(224,224))

plt.imshow(img)

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)
predictions = model.predict(x)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
predictions
# Out:
# array([[1.58403523e-07, 1.80571487e-06, 1.78951868e-05, 5.10046357e-06,
#         9.82119582e-06, 4.74314993e-06, 1.32329269e-05, 3.07584880e-04,
#         3.64760956e-04, 4.39775758e-05, 1.33843230e-06, 5.53330210e-06,
#         1.38882651e-05, 7.49578794e-06, 2.07931479e-03, 6.43877866e-06,
#         2.02069691e-06, 1.11862114e-02, 6.80554309e-04, 2.23086736e-05,
#         2.88076606e-03, 1.76364335e-06, 4.53154280e-06, 4.69765400e-05,
#         1.66521119e-07, 2.92008195e-07, 1.33143532e-08, 5.21819672e-08,
#         4.17340885e-07, 2.13005279e-07, 8.12978305e-06, 1.71595829e-07,
#         1.94979805e-07, 3.35972004e-06, 1.45878921e-05, 5.49569495e-06,
#         6.68936409e-05, 1.22957283e-06, 2.41245313e-09, 5.62645880e-07,
#         2.21818404e-08, 1.13393909e-07, 3.48531159e-07, 2.98577518e-08,
#         1.34989293e-07, 1.12788214e-07, 1.51580011e-07, 1.97776533e-08,
#         3.22616927e-07, 3.23388440e-06, 2.10365142e-05, 4.15270642e-06,
# ...
